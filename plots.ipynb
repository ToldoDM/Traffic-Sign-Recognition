# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("csv/run-W_CNN_ST_Sgd-tag-Training_Training Loss.csv")
df
# Out:
#         Wall time  Step     Value
# 0    1.715874e+09     4  3.765440
# 1    1.715874e+09    18  3.762237
# 2    1.715874e+09    26  3.761262
# 3    1.715874e+09    27  3.752339
# 4    1.715874e+09    40  3.763075
# ..            ...   ...       ...
# 995  1.715875e+09  6779  0.006460
# 996  1.715875e+09  6785  0.017990
# 997  1.715875e+09  6802  0.021507
# 998  1.715875e+09  6806  0.089318
# 999  1.715875e+09  6809  0.044438
#
# [1000 rows x 3 columns]

# %%
asd = (df['Value'])
# asd.append(0.94567893)

# %%
plt.plot(asd)
plt.show()
